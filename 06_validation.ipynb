# %%
print("Bronze:", spark.table("bronze_lap_times").count())
print("Silver:", spark.table("silver_lap_times").count())
print("Gold:", spark.table("gold_fastest_lap").count())
# Out:
# Bronze: 490904
# Silver: 490904
# Gold: 490904

# %%
# %sql
SELECT * FROM silver_lap_times WHERE milliseconds > 50;
-- SELECT COUNT(*) FROM silver_drivers WHERE dob IS  NOT NULL;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
